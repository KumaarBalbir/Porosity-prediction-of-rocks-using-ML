# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm 
from sklearn.model_selection import train_test_split

from sklearn.metrics import r2_score,mean_squared_error

# %%
#storing FC MLR, Random forest,SVR and XGBoost in order, predicted data 
#Furnace cooling
# %store -r phi_pred_FG_FC
# %store -r RF_pred_FG_FC
# %store -r  svr_pred_FG_FC
# %store -r y_pred_FG_FC 
# %store -r knn_pred_FG_FC

# %%
#storing FC MLR, Random forest,SVR and XGBoost in order, predicted data 
#Furnace cooling
# %store -r phi_pred_FG_WC
# %store -r RF_pred_FG_WC
# %store -r  svr_pred_FG_WC
# %store -r y_pred_FG_WC
# %store -r knn_pred_FG_WC

# %%
#storing mesured value 
# %store -r measured_FG_FC
# %store -r measured_FG_WC

# %%
#storing FC MLR, Random forest,SVR and XGBoost in order, predicted data 
#Furnace cooling
# %store -r phi_pred_MG_FC
# %store -r RF_pred_MG_FC
# %store -r  svr_pred_MG_FC
# %store -r y_pred_MG_FC 
# %store -r knn_pred_MG_FC

# %%
#storing FC MLR, Random forest,SVR and XGBoost in order, predicted data 
#Furnace cooling
# %store -r phi_pred_MG_WC
# %store -r RF_pred_MG_WC
# %store -r  svr_pred_MG_WC
# %store -r y_pred_MG_WC
# %store -r knn_pred_MG_WC

# %%
#storing mesured value 
# %store -r measured_MG_FC
# %store -r measured_MG_WC

# %%
#storing FC MLR, Random forest,SVR and XGBoost in order, predicted data 
#Furnace cooling
# %store -r phi_pred_CG_FC
# %store -r RF_pred_CG_FC
# %store -r  svr_pred_CG_FC
# %store -r y_pred_CG_FC
# %store -r knn_pred_CG_FC

# %%
#storing FC MLR, Random forest,SVR and XGBoost in order, predicted data 
#Furnace cooling
# %store -r phi_pred_CG_WC
# %store -r RF_pred_CG_WC
# %store -r  svr_pred_CG_WC
# %store -r y_pred_CG_WC 
# %store -r knn_pred_CG_WC

# %%
#storing mesured value 
# %store -r measured_CG_FC
# %store -r measured_CG_WC

# %%
measured_FG_FC
# Out:
# array([[3.2635 ],
#        [3.2145 ],
#        [3.337  ],
#        [0.94225],
#        [1.82875],
#        [3.052  ],
#        [3.41575],
#        [2.079  ]])

# %%
measured_FG_FC[1][0]
# Out:
# 3.2145

# %%
x_val=[]
for i in range(8):
    x_val.append(measured_FG_FC[i][0])

x_val= np.array(x_val)
x_val
# Out:
# array([3.2635 , 3.2145 , 3.337  , 0.94225, 1.82875, 3.052  , 3.41575,
#        2.079  ])

# %%
plt.figure(figsize=(10,10))
# p1 = 7
# p2 = 0.0
# plt.plot([p1, p2], [p1, p2])
x= x_val
y= x_val
plt.scatter(x_val, x_val, c='crimson',label='Fine grain (R2=0.50)')

plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))


# plt.scatter(measured_FG_FC, phi_pred_FG_FC, c='crimson',label='Fine grain (R2=0.50)')
# plt.scatter(measured_MG_FC,phi_pred_MG_FC, c='g',label='Medium grain (R2=0.86)')
# plt.scatter(measured_CG_FC,phi_pred_CG_FC,c='b',label='Coarse grain (R2=0.91)')


# plt.xlabel('Measured Porosity', fontsize=15)
# plt.ylabel('Predicted Porosity', fontsize=15)


# plt.legend()
# plt.title("Furnace Cooling, Multiple Linear Regression")

plt.show()

# %%
plt.figure(figsize=(5,5))
p1 = 7
p2 = 0.0
plt.plot([p1, p2], [p1, p2])
plt.axis('equal')

plt.scatter(measured_FG_FC, phi_pred_FG_FC,s=70, c='crimson',label='Fine grain (R2=0.50)')
plt.scatter(measured_MG_FC,phi_pred_MG_FC,s=70, c='g',label='Medium grain (R2=0.86)')
plt.scatter(measured_CG_FC,phi_pred_CG_FC,s=70,c='b',label='Coarse grain (R2=0.91)')


plt.xlabel('Measured Porosity', fontsize=15)
plt.ylabel('Predicted Porosity', fontsize=15)


plt.legend()
plt.title("Furnace Cooling, Multiple Linear Regression")

plt.show()

# %%
plt.figure(figsize=(5,5))
p1 = 10
p2 = 0.0
plt.plot([p1, p2], [p1, p2])
plt.axis('equal')

plt.scatter(measured_FG_WC, phi_pred_FG_WC,s=70, c='crimson',label='Fine grain (R2=0.98)')
plt.scatter(measured_MG_WC,phi_pred_MG_WC,s=70, c='g',label='Medium grain (R2=0.25)')
plt.scatter(measured_CG_WC,phi_pred_CG_WC,s=70,c='b',label='Coarse grain (R2=0.99)')


plt.xlabel('Measured Porosity', fontsize=15)
plt.ylabel('Predicted Porosity', fontsize=15)


plt.legend()
plt.title("Water Cooling, Multiple Linear Regression")

plt.show()

# %%
plt.figure(figsize=(5,5))
p1 = 7
p2 = 0.0
plt.plot([p1, p2], [p1, p2])
plt.axis('equal')

plt.scatter(measured_FG_FC, RF_pred_FG_FC,s=70, c='crimson',label='Fine grain (R2=0.98)')
plt.scatter(measured_MG_FC,RF_pred_MG_FC,s=70, c='g',label='Medium grain (R2=0.99)')
plt.scatter(measured_CG_FC,RF_pred_CG_FC,s=70,c='b',label='Coarse grain (R2=0.97)')


plt.xlabel('Measured Porosity', fontsize=15)
plt.ylabel('Predicted Porosity', fontsize=15)


plt.legend()
plt.title("Furnace Cooling, Random Forest")

plt.show()

# %%
plt.figure(figsize=(5,5))
p1 = 10
p2 = 0.0
plt.plot([p1, p2], [p1, p2])
plt.axis('equal')

plt.scatter(measured_FG_WC, RF_pred_FG_WC,s=70, c='crimson',label='Fine grain (R2=0.99)')
plt.scatter(measured_MG_WC,RF_pred_MG_WC,s=70, c='g',label='Medium grain (R2=0.99)')
plt.scatter(measured_CG_WC,RF_pred_CG_WC,s=70,c='b',label='Coarse grain (R2=0.99)')


plt.xlabel('Measured Porosity', fontsize=15)
plt.ylabel('Predicted Porosity', fontsize=15)


plt.legend()
plt.title("Water Cooling, Random Forest")

plt.show()

# %%
plt.figure(figsize=(5,5))
p1 = 7
p2 = 0.0
plt.plot([p1, p2], [p1, p2])
plt.axis('equal')

plt.scatter(measured_FG_FC, svr_pred_FG_FC,s=70, c='crimson',label='Fine grain (R2=0.88)')
plt.scatter(measured_MG_FC,svr_pred_MG_FC,s=70, c='g',label='Medium grain (R2=0.97)')
plt.scatter(measured_CG_FC,svr_pred_CG_FC,s=70,c='b',label='Coarse grain (R2=0.91)')


plt.xlabel('Measured Porosity', fontsize=15)
plt.ylabel('Predicted Porosity', fontsize=15)


plt.legend()
plt.title("Furnace Cooling, Support vector regression")

plt.show()

# %%
plt.figure(figsize=(5,5))
p1 = 10
p2 = 0.0
plt.plot([p1, p2], [p1, p2])
plt.axis('equal')

plt.scatter(measured_FG_WC, svr_pred_FG_WC,s=70, c='crimson',label='Fine grain (R2=0.92)')
plt.scatter(measured_MG_WC,svr_pred_MG_WC,s=70, c='g',label='Medium grain (R2=0.60)')
plt.scatter(measured_CG_WC,svr_pred_CG_WC,s=70,c='b',label='Coarse grain (R2=0.98)')


plt.xlabel('Measured Porosity', fontsize=15)
plt.ylabel('Predicted Porosity', fontsize=15)


plt.legend()
plt.title("Water Cooling, Support vector regression")

plt.show()

# %%
plt.figure(figsize=(5,5))
p1 = 7
p2 = 0.0
plt.plot([p1, p2], [p1, p2])
plt.axis('equal')

plt.scatter(measured_FG_FC, y_pred_FG_FC,s=70, c='crimson',label='Fine grain (R2=0.97)')
plt.scatter(measured_MG_FC,y_pred_MG_FC,s=70, c='g',label='Medium grain (R2=0.98)')
plt.scatter(measured_CG_FC,y_pred_CG_FC,s=70,c='b',label='Coarse grain (R2=0.91)')


plt.xlabel('Measured Porosity', fontsize=15)
plt.ylabel('Predicted Porosity', fontsize=15)


plt.legend()
plt.title("Furnace Cooling, XGBoost")

plt.show()

# %%
plt.figure(figsize=(5,5))
p1 = 10
p2 = 0.0
plt.plot([p1, p2], [p1, p2])
plt.axis('equal')

plt.scatter(measured_FG_WC, y_pred_FG_WC,s=70, c='crimson',label='Fine grain (R2=0.98)')
plt.scatter(measured_MG_WC,y_pred_MG_WC, s=70,c='g',label='Medium grain (R2=0.96)')
plt.scatter(measured_CG_WC,y_pred_CG_WC,s=70,c='b',label='Coarse grain (R2=0.98)')


plt.xlabel('Measured Porosity', fontsize=15)
plt.ylabel('Predicted Porosity', fontsize=15)


plt.legend()
plt.title("Water Cooling, XGBoost")

plt.show()

# %%
plt.figure(figsize=(5,5))
p1 = 7
p2 = 0.0
plt.plot([p1, p2], [p1, p2])
plt.axis('equal')

plt.scatter(measured_FG_FC, knn_pred_FG_FC, s=70, c='crimson',label='Fine grain (R2=0.98)')
plt.scatter(measured_MG_FC,knn_pred_MG_FC,s=70, c='g',label='Medium grain (R2=0.99)')
plt.scatter(measured_CG_FC,knn_pred_CG_FC,s=70,c='b',label='Coarse grain (R2=0.96)')


plt.xlabel('Measured Porosity', fontsize=15)
plt.ylabel('Predicted Porosity', fontsize=15)


plt.legend()
plt.title("Furnace Cooling, K-nearest neighbors")

plt.show()

# %%
plt.figure(figsize=(5,5))
p1 = 10
p2 = 0.0
plt.plot([p1, p2], [p1, p2])
plt.axis('equal')

plt.scatter(measured_FG_WC, y_pred_FG_WC,s=70, c='crimson',label='Fine grain (R2=0.99)')
plt.scatter(measured_MG_WC,y_pred_MG_WC,s=70, c='g',label='Medium grain (R2=0.99)')
plt.scatter(measured_CG_WC,y_pred_CG_WC,s=70,c='b',label='Coarse grain (R2=0.99)')


plt.xlabel('Measured Porosity', fontsize=15)
plt.ylabel('Predicted Porosity', fontsize=15)


plt.legend()
plt.title("Water Cooling, K-nearest neighbors")

plt.show()
